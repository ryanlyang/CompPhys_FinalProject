# %%
import h5py
import numpy as np

# %%
f = h5py.File("test.h5", "r")

# %%
def print_h5(name, obj):
    print(name)
    if isinstance(obj, h5py.Dataset):
        print("  shape:", obj.shape, "dtype:", obj.dtype)

f.visititems(print_h5)
# Out:
# fjet_C2
#   shape: (2484117,) dtype: float32
# fjet_D2
#   shape: (2484117,) dtype: float32
# fjet_ECF1
#   shape: (2484117,) dtype: float32
# fjet_ECF2
#   shape: (2484117,) dtype: float32
# fjet_ECF3
#   shape: (2484117,) dtype: float32
# fjet_L2
#   shape: (2484117,) dtype: float32
# fjet_L3
#   shape: (2484117,) dtype: float32
# fjet_Qw
#   shape: (2484117,) dtype: float32
# fjet_Split12
#   shape: (2484117,) dtype: float32
# fjet_Split23
#   shape: (2484117,) dtype: float32
# fjet_Tau1_wta
#   shape: (2484117,) dtype: float32
# fjet_Tau2_wta
#   shape: (2484117,) dtype: float32
# fjet_Tau3_wta
#   shape: (2484117,) dtype: float32
# fjet_Tau4_wta
#   shape: (2484117,) dtype: float32
# fjet_ThrustMaj
#   shape: (2484117,) dtype: float32
# fjet_clus_E
#   shape: (2484117, 200) dtype: float32
# fjet_clus_eta
#   shape: (2484117, 200) dtype: float32
# fjet_clus_phi
#   shape: (2484117, 200) dtype: float32
# fjet_clus_pt
#   shape: (2484117, 200) dtype: float32
# fjet_eta
# ...

# %%
import importlib
import tool

importlib.reload(tool)

# Raw constituent-level distributions from the four H5 inputs.
tool.inspect_dist_h5(f, 'fjet_clus_eta', n_jets=200000, max_particles=100, mask_zero=True, bins=120)
tool.inspect_dist_h5(f, 'fjet_clus_phi', n_jets=200000, max_particles=100, mask_zero=True, bins=120)
tool.inspect_dist_h5(f, 'fjet_clus_pt', n_jets=200000, max_particles=100, mask_zero=True, transform='log', bins=120)
tool.inspect_dist_h5(f, 'fjet_clus_E', n_jets=200000, max_particles=100, mask_zero=True, transform='log', bins=120)
# Out:
# [fjet_clus_eta] used_jets=200000 raw_shape=(2484117, 200)
#
# [fjet_clus_eta] used_values=10,858,486
#   min=-2.98318 max=2.99247 mean=0.00255619 std=0.846018
#   p  0.1=-2.18631
#   p    1=-1.83755
#   p    5=-1.41293
#   p   25=-0.598638
#   p   50=0.0025604
#   p   75=0.603455
#   p   95=1.41635
#   p   99=1.84078
#   p 99.9=2.18872
# [fjet_clus_phi] used_jets=200000 raw_shape=(2484117, 200)
#
# [fjet_clus_phi] used_values=10,858,486
#   min=-3.14159 max=3.14159 mean=0.000726311 std=1.81481
#   p  0.1=-3.13509
#   p    1=-3.07922
#   p    5=-2.82625
#   p   25=-1.56805
#   p   50=-0.000822231
#   p   75=1.57659
#   p   95=2.82575
#   p   99=3.07897
#   p 99.9=3.13497
# [fjet_clus_pt] used_jets=200000 raw_shape=(2484117, 200)
#
# [fjet_clus_pt] used_values=10,858,486
#   min=4.60566 max=15.0651 mean=8.79381 std=1.5177
#   p  0.1=5.55338
#   p    1=6.10735
#   p    5=6.58094
#   p   25=7.75289
#   p   50=8.59625
#   p   75=9.68234
#   p   95=11.676
#   p   99=12.919
# ...

# %%
# Jet-frame distributions derived only from constituent pt/eta/phi/E.
tool.inspect_jet_frame_constituent_distributions(
    f,
    n_jets=200000,
    max_particles=100,
    bins=120,
)
# Out:
# [dEta] used_values=10,858,486
#   min=-1.47191 max=1.45756 mean=-0.000125849 std=0.21221
#   p  0.1=-0.904921
#   p    1=-0.645577
#   p    5=-0.354108
#   p   25=-0.0815298
#   p   50=-4.38624e-05
#   p   75=0.0812646
#   p   95=0.353396
#   p   99=0.645525
#   p 99.9=0.905031
#
# [dPhi] used_values=10,858,486
#   min=-1.41141 max=1.3974 mean=-4.62956e-05 std=0.217293
#   p  0.1=-0.902276
#   p    1=-0.659123
#   p    5=-0.365548
#   p   25=-0.0830963
#   p   50=-1.5788e-05
#   p   75=0.0832377
#   p   95=0.365578
#   p   99=0.658678
#   p 99.9=0.903544
#
# [log_pt] used_values=10,858,486
#   min=4.60566 max=15.0651 mean=8.79381 std=1.5177
#   p  0.1=5.55338
#   p    1=6.10735
#   p    5=6.58094
#   p   25=7.75289
#   p   50=8.59625
#   p   75=9.68234
#   p   95=11.676
#   p   99=12.919
#   p 99.9=14.0283
#
# [log_E] used_values=10,858,486
#   min=4.61045 max=15.2044 mean=9.08464 std=1.52125
#   p  0.1=5.71312
#   p    1=6.31995
#   p    5=6.86596
#   p   25=8.02959
# ...

# %%
# 前 N 个 jet 在 jet-axis 和 mean/std 标准化后的四维特征分布。
importlib.reload(tool)

tool.inspect_standardized_jet_frame_constituent_distributions(
    f,
    n_jets=200000,
    max_particles=100,
    bins=120,
)
# Out:
# [dEta_std] used_values=10,858,486
#   min=-6.93549 max=6.86904 mean=1.12656e-17 std=1
#   p  0.1=-4.26367
#   p    1=-3.04157
#   p    5=-1.66807
#   p   25=-0.3836
#   p   50=0.000386345
#   p   75=0.383537
#   p   95=1.66591
#   p   99=3.04251
#   p 99.9=4.26538
#
# [dPhi_std] used_values=10,858,486
#   min=-6.49524 max=6.43118 mean=1.82176e-17 std=1
#   p  0.1=-4.15214
#   p    1=-3.03313
#   p    5=-1.68207
#   p   25=-0.382203
#   p   50=0.000140399
#   p   75=0.38328
#   p   95=1.68264
#   p   99=3.03151
#   p 99.9=4.1584
#
# [log_pt_std] used_values=10,858,486
#   min=-2.75954 max=4.13214 mean=4.66746e-16 std=1
#   p  0.1=-2.1351
#   p    1=-1.77009
#   p    5=-1.45804
#   p   25=-0.685855
#   p   50=-0.130172
#   p   75=0.585447
#   p   95=1.89903
#   p   99=2.71807
#   p 99.9=3.44894
#
# [log_E_std] used_values=10,858,486
#   min=-2.94113 max=4.02286 mean=-1.01139e-15 std=1
#   p  0.1=-2.21628
#   p    1=-1.81738
#   p    5=-1.45846
#   p   25=-0.693539
#   p   50=-0.130846
# ...

# %%
# Single-jet constituent views. Set jet_idx to an integer if you want a fixed jet.
jet_idx = 539615
tool.plot_single_jet_constituent_views(
    f,
    jet_idx=jet_idx,
    max_particles=100,
    # color_by=('pt', '|p|', 'E'),
    color_by=('pt',)
)
# Out:
# Jet index: 539615
# Constituents used: 78
# p min/max: 952.507 / 198641
# E min/max: 957.476 / 198652
# Jet axis eta/phi: -1.74538 / 0.706226
# 539615

# %%
# Standardized dEta-dPhi view in the jet frame.
importlib.reload(tool)

jet_idx = None  # Set an integer here if you want a fixed jet.
stats_n_jets = 200000
max_particles = 100

tool.plot_single_jet_standardized_jet_frame(
    f,
    jet_idx=jet_idx,
    max_particles=max_particles,
    stats_n_jets=stats_n_jets,
    color_by='pt',
)
# Out:
# Jet index: 2087497
# Constituents used: 50
# Jet axis eta/phi: 0.924469 / -1.57861
# Standardization stats: dEta(mean=-0.000125849, std=0.21221), dPhi(mean=-4.62956e-05, std=0.217293)
# Stats jets used: 200000
# 2087497

# %%
# 加入常用 smear 效果后，查看单个 jet 在三种坐标下的 dEta-dPhi 热图。
importlib.reload(tool)

jet_idx = None  # 设成整数可固定某个 jet。
max_particles = 100
stats_n_jets = 200000

smear_cfg = tool.CommonSmearCfg(
    pt_threshold_offline=0,
    pt_threshold_hlt=0,
    pt_resolution=0.10,
    eta_resolution=0.03,
    phi_resolution=0.03,
)

tool.plot_single_jet_smeared_coordinate_views(
    f,
    jet_idx=jet_idx,
    max_particles=max_particles,
    stats_n_jets=stats_n_jets,
    color_by='pt',
    cfg=smear_cfg,
    seed=42,
)
# Out:
# Jet index: 331690
# Smeared constituents used: 86
# Smear cfg: pt_thr_off=0, pt_thr_hlt=0, pt_res=0.1, eta_res=0.03, phi_res=0.03
# Jet axis eta/phi after smear: 1.35025 / 1.12355
# Standardization stats after smear: dEta(mean=-0.000153819, std=0.214579), dPhi(mean=-4.42785e-05, std=0.219534)
# 331690

# %%
# 只在标准化空间里看 smear 前后的对比，放在同一张图中。
importlib.reload(tool)

jet_idx = None  # 设成整数可固定某个 jet。
max_particles = 20
stats_n_jets = 200000

smear_cfg = tool.CommonSmearCfg(
    pt_threshold_offline=0,
    pt_threshold_hlt=0,
    pt_resolution=0.10,
    eta_resolution=0.03,
    phi_resolution=0.03,
)

tool.plot_single_jet_smeared_std_comparison(
    f,
    jet_idx=jet_idx,
    max_particles=max_particles,
    stats_n_jets=stats_n_jets,
    cfg=smear_cfg,
    seed=42,
    cmap='turbo',
)
# Out:
# Jet index: 1481488
# Matched constituents used: 20
# Smear cfg: pt_thr_off=0, pt_thr_hlt=0, pt_res=0.1, eta_res=0.03, phi_res=0.03
# Base jet axis eta/phi: 0.251352 / 1.27574
# Smeared jet axis eta/phi: 0.234149 / 1.26881
# Standardized shift magnitude: mean=0.24153, max=0.559527
# 1481488
